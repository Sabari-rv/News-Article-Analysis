# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (4.24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: filelock in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (2022.9.13)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (1.23.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from transformers) (0.10.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from requests->transformers) (2022.9.24)

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: numpy>=1.17 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (1.23.3)
# Requirement already satisfied: dill<0.3.6 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (4.64.1)
# Requirement already satisfied: pandas in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (1.4.4)
# Requirement already satisfied: xxhash in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (3.1.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (2022.11.0)
# Requirement already satisfied: packaging in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: multiprocess in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (0.70.13)
# Requirement already satisfied: aiohttp in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (3.8.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (10.0.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (2.28.1)
# Requirement already satisfied: responses<0.19 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (6.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from datasets) (0.10.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: filelock in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /Users/prashanthsingaravelan/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
import datasets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 import datasets
#
# ModuleNotFoundError: No module named 'datasets'

# %%
from datasets import load_dataset

xsum = load_dataset("xsum", split="train[:20%]+test[:20%]")
print(xsum)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 from datasets import load_dataset
#       3 xsum = load_dataset("xsum", split="train[:20%]+test[:20%]")
#       4 print(xsum)
#
# ModuleNotFoundError: No module named 'datasets'

# %%
xsum = xsum.train_test_split(test_size=0.25)

# %%
xsum["train"][0]
# Out:
# {'document': 'A specialist animal rescue advisor and firefighters released the horse, named Spencer, after his leg broke through the floor of the trailer in Droxford, Hampshire, on Sunday afternoon.\nThe horse was anesthetised before the trailer wheels were removed.\nHampshire Fire and Rescue said it was "complicated rescue" but Spencer had suffered no lasting damage.',
#  'summary': 'A horse has been freed from a transporter after his hind leg was trapped between the rear wheels.',
#  'id': '35628962'}

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("t5-small")
# Out:
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5_fast.py:166: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,

# %%
prefix = "summarize: "


def preprocess_function(examples):
    inputs = [prefix + doc.strip().replace("\n","") for doc in examples["document"]]
    model_inputs = tokenizer(inputs, max_length=1024, truncation=True)

    labels = tokenizer(text_target=examples["summary"], max_length=128, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_xsum = xsum.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/33 [00:00<?, ?ba/s]
#   0%|          | 0/11 [00:00<?, ?ba/s]

# %%
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

model = AutoModelForSeq2SeqLM.from_pretrained("t5-small")
print('\nModel type:', str(type(model)))
# Out:
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Model type: <class 'transformers.models.t5.modeling_t5.T5ForConditionalGeneration'>

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="/content/drive/MyDrive/NLP Project/Summarize/results-summarisation",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=7,
    fp16=True,
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_xsum["train"],
    eval_dataset=tokenized_xsum["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='4403' max='28273' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 4403/28273 32:21 < 2:55:32, 2.27 it/s, Epoch 1.09/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.813500</td>
#       <td>2.565406</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-2500/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3500
# Configuration saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3500/config.json
# Model weights saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-3500/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-4000
# Configuration saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-4000/config.json
# Model weights saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-4000/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: summary, document, id. If summary, document, id are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 10769
#   Batch size = 8

# %%
xsum['train']

# %%
from transformers import pipeline
from transformers import AutoTokenizer
from transformers import DataCollatorForSeq2Seq

# %%
tokenizer_cus = AutoTokenizer.from_pretrained("/content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-28000")
model_cus = AutoModelForSeq2SeqLM.from_pretrained("/content/drive/MyDrive/NLP Project/Summarize/results-summarisation/checkpoint-28000")

# %%
summarize=pipeline('summarization',model=model_cus,tokenizer=tokenizer_cus,max_length = 85)

# %%
text="""Musk was born and grew up in Pretoria, South Africa. He attended the University of Pretoria before moving to Canada at age 17, acquiring citizenship through his Canadian-born mother. Two years later, he matriculated at Queen's University and transferred to the University of Pennsylvania, where he received bachelor's degrees in economics and physics. He moved to California in 1995 to attend Stanford University but decided to instead pursue a business career, co-founding the web software company Zip2 with his brother, Kimbal. The startup was acquired by Compaq for $307 million in 1999. The same year, Musk co-founded the online bank X.com, which merged with Confinity in 2000 to form PayPal. eBay bought PayPal in 2002 for $1.5 billion. """

# %%
summary=summarize(text)

# %%
summary[0]['summary_text']
